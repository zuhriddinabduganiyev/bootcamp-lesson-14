# %%
import pandas as pd

# %%
data = pd.read_csv("sample.csv")
data.head()
# Out:
#                                 INSTNM    OPEID  REGION  SAT_AVG_ALL  PCTPELL  \
# 0             Alabama A & M University   100200       5        850.0   0.7249
# 1  University of Alabama at Birmingham   105200       5       1147.0   0.3505
# 2                   Amridge University  2503400       5          NaN   0.7455
# 3  University of Alabama in Huntsville   105500       5       1221.0   0.3179
# 4             Alabama State University   100500       5        844.0   0.7567
#
#    PCTFLOAN  ADM_RATE_ALL       UG  AVGFACSAL COMPL_RPY_5YR_RT  ... CONTROL  \
# 0    0.8159      0.653841   4380.0     7017.0      0.477631579  ...       1
# 1    0.5218      0.604275  10331.0    10221.0      0.673230442  ...       1
# 2    0.8781           NaN     98.0     3217.0      0.636363636  ...       2
# 3    0.4589      0.811971   5220.0     9514.0      0.762222222  ...       1
# 4    0.7692      0.463858   4348.0     7940.0       0.43006993  ...       1
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6702 entries, 0 to 6701
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   INSTNM            6702 non-null   object
#  1   OPEID             6702 non-null   int64
#  2   REGION            6702 non-null   int64
#  3   SAT_AVG_ALL       1387 non-null   float64
#  4   PCTPELL           6066 non-null   float64
#  5   PCTFLOAN          6066 non-null   float64
#  6   ADM_RATE_ALL      2180 non-null   float64
#  7   UG                4367 non-null   float64
#  8   AVGFACSAL         4104 non-null   float64
#  9   COMPL_RPY_5YR_RT  5708 non-null   object
#  10  DEBT_MDN          6681 non-null   object
#  11  MEDIAN_HH_INC     4993 non-null   object
#  12  ICLEVEL           6702 non-null   int64
#  13  HIGHDEG           6702 non-null   int64
#  14  CONTROL           6702 non-null   int64
#  15  WOMENONLY         6368 non-null   float64
# ...

# %%
data.describe()
# Out:
#               OPEID       REGION  SAT_AVG_ALL      PCTPELL     PCTFLOAN  \
# count  6.702000e+03  6702.000000  1387.000000  6066.000000  6066.000000
# mean   1.788528e+06     4.602954  1065.332372     0.502318     0.490676
# std    3.304120e+06     2.177145   134.879236     0.220404     0.279644
# min    1.002000e+05     0.000000   708.000000     0.000000     0.000000
# 25%    3.188250e+05     3.000000   981.500000     0.338525     0.285725
# 50%    1.005302e+06     5.000000  1048.000000     0.483850     0.548200
# 75%    2.598900e+06     6.000000  1127.000000     0.666700     0.704500
# max    8.209884e+07     9.000000  1544.000000     1.000000     1.000000
#
#        ADM_RATE_ALL            UG     AVGFACSAL      ICLEVEL      HIGHDEG  \
# count   2180.000000   4367.000000   4104.000000  6702.000000  6702.000000
# mean       0.681821   2945.242501   6451.342105     1.811698     2.276783
# std        0.204033   4974.178446   2376.043146     0.817686     1.324162
# ...

# %%
data.isnull().mean() * 100
# Out:
# INSTNM               0.000000
# OPEID                0.000000
# REGION               0.000000
# SAT_AVG_ALL         79.304685
# PCTPELL              9.489705
# PCTFLOAN             9.489705
# ADM_RATE_ALL        67.472396
# UG                  34.840346
# AVGFACSAL           38.764548
# COMPL_RPY_5YR_RT    14.831394
# DEBT_MDN             0.313339
# MEDIAN_HH_INC       25.499851
# ICLEVEL              0.000000
# HIGHDEG              0.000000
# CONTROL              0.000000
# WOMENONLY            4.983587
# MENONLY              4.983587
# LOCALE               4.983587
# Tuition             14.428529
# Degree_Type          0.000000
# Ownership            0.000000
# Regions              0.000000
# Locales              4.983587
# Locale_Short         5.028350
# dtype: float64

# %%
data.head().T
# Out:
#                                          0  \
# INSTNM            Alabama A & M University
# OPEID                               100200
# REGION                                   5
# SAT_AVG_ALL                          850.0
# PCTPELL                             0.7249
# PCTFLOAN                            0.8159
# ADM_RATE_ALL                      0.653841
# UG                                  4380.0
# AVGFACSAL                           7017.0
# COMPL_RPY_5YR_RT               0.477631579
# DEBT_MDN                             14600
# MEDIAN_HH_INC                     49720.22
# ICLEVEL                                  1
# HIGHDEG                                  4
# CONTROL                                  1
# WOMENONLY                              0.0
# MENONLY                                0.0
# LOCALE                                12.0
# Tuition                            13435.0
# Degree_Type                       Graduate
# Ownership                           Public
# ...

# %%
data.select_dtypes("number")
# Out:
#         OPEID  REGION  SAT_AVG_ALL  PCTPELL  PCTFLOAN  ADM_RATE_ALL       UG  \
# 0      100200       5        850.0   0.7249    0.8159      0.653841   4380.0
# 1      105200       5       1147.0   0.3505    0.5218      0.604275  10331.0
# 2     2503400       5          NaN   0.7455    0.8781           NaN     98.0
# 3      105500       5       1221.0   0.3179    0.4589      0.811971   5220.0
# 4      100500       5        844.0   0.7567    0.7692      0.463858   4348.0
# ...       ...     ...          ...      ...       ...           ...      ...
# 6697  4205801       8          NaN      NaN       NaN           NaN      NaN
# 6698   869423       4          NaN      NaN       NaN           NaN      NaN
# 6699  4220901       3          NaN      NaN       NaN           NaN      NaN
# 6700  4223701       8          NaN      NaN       NaN           NaN      NaN
# 6701  4228101       8          NaN      NaN       NaN           NaN      NaN
#
# ...

# %%
data.select_dtypes("object")
# Out:
#                                                  INSTNM COMPL_RPY_5YR_RT  \
# 0                              Alabama A & M University      0.477631579
# 1                   University of Alabama at Birmingham      0.673230442
# 2                                    Amridge University      0.636363636
# 3                   University of Alabama in Huntsville      0.762222222
# 4                              Alabama State University       0.43006993
# ...                                                 ...              ...
# 6697          SAE Institute of Technology San Francisco              NaN
# 6698                  Rasmussen College - Overland Park      0.598980065
# 6699  National Personal Training Institute of Cleveland              NaN
# 6700  Bay Area Medical Academy - San Jose Satellite ...              NaN
# 6701                        High Desert Medical College              NaN
#
#      DEBT_MDN MEDIAN_HH_INC Degree_Type           Ownership      Regions  \
# ...

# %%
data[['DEBT_MDN', 'COMPL_RPY_5YR_RT', 'MEDIAN_HH_INC']]
# Out:
#      DEBT_MDN COMPL_RPY_5YR_RT MEDIAN_HH_INC
# 0       14600      0.477631579      49720.22
# 1       14250      0.673230442      55735.22
# 2       11082      0.636363636       53683.7
# 3       15000      0.762222222      58688.62
# 4       15274       0.43006993       46065.2
# ...       ...              ...           ...
# 6697     5500              NaN           NaN
# 6698  10851.5      0.598980065           NaN
# 6699     6333              NaN           NaN
# 6700     5500              NaN           NaN
# 6701     7519              NaN           NaN
#
# [6702 rows x 3 columns]

# %%
data = pd.read_csv("sample.csv")

# %%
data['DEBT_MDN'] = pd.to_numeric(data['DEBT_MDN'], errors="coerce")
data['COMPL_RPY_5YR_RT'] = pd.to_numeric(data['COMPL_RPY_5YR_RT'], errors="coerce")
data['MEDIAN_HH_INC'] = pd.to_numeric(data['MEDIAN_HH_INC'], errors="coerce")
# data = data.dropna().reset_index(drop=True)
data
# Out:
#                                                  INSTNM    OPEID  REGION  \
# 0                              Alabama A & M University   100200       5
# 1                   University of Alabama at Birmingham   105200       5
# 2                                    Amridge University  2503400       5
# 3                   University of Alabama in Huntsville   105500       5
# 4                              Alabama State University   100500       5
# ...                                                 ...      ...     ...
# 6697          SAE Institute of Technology San Francisco  4205801       8
# 6698                  Rasmussen College - Overland Park   869423       4
# 6699  National Personal Training Institute of Cleveland  4220901       3
# 6700  Bay Area Medical Academy - San Jose Satellite ...  4223701       8
# 6701                        High Desert Medical College  4228101       8
#
#       SAT_AVG_ALL  PCTPELL  PCTFLOAN  ADM_RATE_ALL       UG  AVGFACSAL  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
g = sns.FacetGrid(data, col='HIGHDEG')
g.map(sns.boxplot, 'Tuition')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/axisgrid.py:718: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
data["COMPL_RPY_5YR_RT"].nunique()
# Out:
# 2760

# %%
fig, ax = plt.subplots(figsize=(12, 8))
pd.to_numeric(data["COMPL_RPY_5YR_RT"], errors='coerce').hist(color="orange")
plt.show()

# %%
data.select_dtypes("object").head()
# Out:
#                                 INSTNM Degree_Type           Ownership  \
# 0             Alabama A & M University    Graduate              Public
# 1  University of Alabama at Birmingham    Graduate              Public
# 2                   Amridge University    Graduate  Private non-profit
# 3  University of Alabama in Huntsville    Graduate              Public
# 4             Alabama State University    Graduate              Public
#
#       Regions        Locales Locale_Short
# 0  South East  City: Midsize         City
# 1  South East  City: Midsize         City
# 2  South East  City: Midsize         City
# 3  South East  City: Midsize         City
# 4  South East  City: Midsize         City

# %%
data.value_counts(subset=['REGION', 'Ownership'])
# Out:
# REGION  Ownership
# 5       Private for-profit    723
#         Public                553
# 8       Private for-profit    429
# 2       Private non-profit    409
# 5       Private non-profit    394
# 2       Private for-profit    382
# 3       Private for-profit    378
# 6       Private for-profit    349
# 3       Private non-profit    308
#         Public                287
# 2       Public                284
# 8       Public                257
# 6       Public                248
# 8       Private non-profit    245
# 4       Public                199
#         Private non-profit    184
#         Private for-profit    176
# 1       Private non-profit    161
# 7       Private for-profit    129
# 1       Private for-profit    119
# 6       Private non-profit    108
# 1       Public                104
# 7       Public                 82
# 9       Private for-profit     72
#         Private non-profit     52
# 7       Private non-profit     41
# 9       Public                 28
# ...

# %%
data["COMPL_RPY_5YR_RT_NUMERIC"] = pd.to_numeric(data["COMPL_RPY_5YR_RT"], errors='coerce')
data.groupby(by=['REGION', 'Ownership', "Degree_Type"])['COMPL_RPY_5YR_RT_NUMERIC'].agg(['count', 'mean', 'median'])
# Out:
#                                        count      mean    median
# REGION Ownership          Degree_Type
# 0      Public             Graduate         0       NaN       NaN
# 1      Private for-profit Associates       3  0.427343  0.387928
#                           Bachelors        4  0.705056  0.703487
#                           Certificate     63  0.473661  0.449203
#                           Graduate         4  0.575790  0.541163
# ...                                      ...       ...       ...
# 9      Public             Associates       0       NaN       NaN
#                           Bachelors        0       NaN       NaN
#                           Certificate      0       NaN       NaN
#                           Graduate         4  0.644076  0.672881
#                           Non-degree       1  0.669291  0.669291
#
# [134 rows x 3 columns]

# %%
import pandas as pd
import numpy as np

group_cols = ['REGION', 'Ownership', "Degree_Type", "Locale_Short"]
def fillna_grouped(data, group_cols, column, method):
    if method == 'median':
        return data.groupby(by=group_cols)[column].transform(
            lambda x: x.fillna(np.nanmedian(x)) if not x.isnull().all() else x
        )
    elif method == 'mean':
        return data.groupby(by=group_cols)[column].transform(
            lambda x: x.fillna(np.nanmean(x)) if not x.isnull().all() else x
        )
    else:
        raise ValueError("Method must be either 'median' or 'mean'")
data['COMPL_RPY_5YR_RT_NUMERIC_FILLNA'] = fillna_grouped(data, group_cols, 'COMPL_RPY_5YR_RT_NUMERIC', 'median')
data
# Out:
#                                                  INSTNM    OPEID  REGION  \
# 0                              Alabama A & M University   100200       5
# 1                   University of Alabama at Birmingham   105200       5
# 2                                    Amridge University  2503400       5
# 3                   University of Alabama in Huntsville   105500       5
# 4                              Alabama State University   100500       5
# ...                                                 ...      ...     ...
# 6697          SAE Institute of Technology San Francisco  4205801       8
# 6698                  Rasmussen College - Overland Park   869423       4
# 6699  National Personal Training Institute of Cleveland  4220901       3
# 6700  Bay Area Medical Academy - San Jose Satellite ...  4223701       8
# 6701                        High Desert Medical College  4228101       8
#
#       SAT_AVG_ALL  PCTPELL  PCTFLOAN  ADM_RATE_ALL       UG  AVGFACSAL  \
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(12, 8))
data['COMPL_RPY_5YR_RT_NUMERIC'].plot(kind='hist', ax=ax, alpha=0.5, color='blue', bins=20, label='Numeric')
data['COMPL_RPY_5YR_RT_NUMERIC_FILLNA'].plot(kind='hist', ax=ax, alpha=0.5, color='green', bins=20, label='Fillna_Median')
data['COMPL_RPY_5YR_RT_NUMERIC_FILLNA_MEAN'].plot(kind='hist', ax=ax, alpha=0.5, color='red', bins=20, label='Fillna_Mean')
ax.set_xlabel('Value')
ax.set_ylabel('Frequency')
ax.legend()
plt.grid()
plt.title('Histograms of NaN, Fillna_Median, Fillna_Mean')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(12, 8))
data['COMPL_RPY_5YR_RT_NUMERIC'].plot(kind='kde', ax=ax, alpha=0.5, color='blue',  label='Numeric')
data['COMPL_RPY_5YR_RT_NUMERIC_FILLNA'].plot(kind='kde', ax=ax, alpha=0.5, color='green',  label='Fillna_Median')
data['COMPL_RPY_5YR_RT_NUMERIC_FILLNA_MEAN'].plot(kind='kde', ax=ax, alpha=0.5, color='red',  label='Fillna_Mean')
ax.set_xlabel('Value')
ax.set_ylabel('Frequency')
ax.legend()
plt.grid()
plt.title('Histograms of NaN, Fillna_Median, Fillna_Mean')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data["COMPL_RPY_5YR_RT_NUMERIC"].describe()
# Out:
# count    4451.000000
# mean        0.614998
# std         0.195281
# min         0.098837
# 25%         0.461126
# 50%         0.632867
# 75%         0.771980
# max         0.974048
# Name: COMPL_RPY_5YR_RT_NUMERIC, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(12, 8))
pd.to_numeric(data["DEBT_MDN"], errors='coerce').hist()
plt.show()

# %%
data["DEBT_MDN_NUMERIC"] = pd.to_numeric(data["DEBT_MDN"], errors='coerce')
data["DEBT_MDN_NUMERIC"] = data["DEBT_MDN_NUMERIC"].fillna(data["DEBT_MDN_NUMERIC"].median())

# %%
data["DEBT_MDN_NUMERIC"].describe() - pd.to_numeric(data["DEBT_MDN"], errors='coerce').describe()
# Out:
# count    938.000000
# mean    -260.877281
# std     -359.996411
# min        0.000000
# 25%      613.000000
# 50%        0.000000
# 75%     -750.000000
# max        0.000000
# dtype: float64

# %%
plt.figure(figsize=(12,8))
pd.to_numeric(data["DEBT_MDN"], errors='coerce').hist()
plt.show()

# %%
plt.figure(figsize=(12,8))
data["DEBT_MDN_NUMERIC"].hist()
plt.show()

# %%
data[data['DEBT_MDN_NUMERIC'].isnull()]['DEBT_MDN'].unique()
# Out:
# array([], dtype=float64)

# %%
data
# Out:
#                                                  INSTNM    OPEID  REGION  \
# 0                              Alabama A & M University   100200       5
# 1                   University of Alabama at Birmingham   105200       5
# 2                                    Amridge University  2503400       5
# 3                   University of Alabama in Huntsville   105500       5
# 4                              Alabama State University   100500       5
# ...                                                 ...      ...     ...
# 6697          SAE Institute of Technology San Francisco  4205801       8
# 6698                  Rasmussen College - Overland Park   869423       4
# 6699  National Personal Training Institute of Cleveland  4220901       3
# 6700  Bay Area Medical Academy - San Jose Satellite ...  4223701       8
# 6701                        High Desert Medical College  4228101       8
#
#       SAT_AVG_ALL  PCTPELL  PCTFLOAN  ADM_RATE_ALL       UG  AVGFACSAL  \
# ...

# %%
g = sns.FacetGrid(data, col='HIGHDEG')
g.map(plt.scatter, 'Tuition', 'SAT_AVG_ALL')
plt.show()

# %%
sns.lmplot(data=data, x="Tuition", y="SAT_AVG_ALL",col="HIGHDEG")
plt.show()

# %%
g = sns.PairGrid(data, vars=["Tuition","SAT_AVG_ALL"])
g = g.map(sns.scatterplot)

# %%
g = sns.PairGrid(data, vars=["Tuition", "SAT_AVG_ALL"])
g = g.map_diag(sns.histplot)
g = g.map_offdiag(sns.scatterplot)

# %%
sns.pairplot(data, vars=["Tuition","SAT_AVG_ALL"], kind="reg",diag_kind="hist")
plt.show()

# %%
g = sns.PairGrid(data, vars=['Tuition','SAT_AVG_ALL'])
g = g.map_diag(sns.boxplot)
g = g.map_offdiag(sns.scatterplot)

# %%
sns.pairplot(data.query("REGION < 3"), vars=['Tuition','SAT_AVG_ALL', 'PCTPELL'], hue="REGION",palette="husl", plot_kws={'alpha':0.5})
plt.show()

# %%
g = sns.JointGrid(data=data, x="Tuition", y="ADM_RATE_ALL")
g.plot(sns.regplot, sns.histplot)
plt.show()

# %%
g = sns.JointGrid(data=data, x="Tuition", y="ADM_RATE_ALL")
g = g.plot_joint(sns.kdeplot)
g = g.plot_marginals(sns.kdeplot, shade=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/axisgrid.py:1883: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, ax=self.ax_marg_x, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/axisgrid.py:1889: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(y=self.y, ax=self.ax_marg_y, **kwargs)

# %%
sns.jointplot(data=data, x="Tuition", y="ADM_RATE_ALL", kind='hex')
plt.show()

# %%
g = (sns.jointplot(x="Tuition",
                    y="ADM_RATE_ALL",
                    kind="scatter",
                    xlim=(0, 25000),data=data.query('UG < 2500 &Ownership == "Public"')).plot_joint(sns.kdeplot))
